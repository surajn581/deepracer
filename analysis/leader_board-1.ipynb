# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML

import urllib.request
from urllib.error import HTTPError

pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
df_leaderboards = pd.read_csv('https://raw.githubusercontent.com/aws-deepracer-community/deepracer-race-data/main/raw_data/leaderboards/leaderboards.csv')
df_leaderboards.head()
# Out:
#    Rank                                                Arn  \
# 0     1  arn:aws:deepracer:us-east-1::leaderboard/prese...
# 1     2  arn:aws:deepracer:us-east-1::leaderboard/seaso...
# 2     3  arn:aws:deepracer:us-east-1::leaderboard/seaso...
# 3     4  arn:aws:deepracer:us-east-1::leaderboard/seaso...
# 4     5  arn:aws:deepracer:us-east-1::leaderboard/seaso...
#
#                          Name  \
# 0  Summit Speedway Pre-season
# 1                 London Loop
# 2                Kumo Torakku
# 3         Empire City Circuit
# 4               Shanghai Sudu
#
#                                          Description     LaunchTime  \
# 0  Take part in the Summit Speedway, the pre-seas...  1555516800000
# 1  Race in the London Loop, the first stop of the...  1556553600000
# 2  Continue racing and building up League points ...  1559595600000
# 3  The July race is now open and is the third sto...  1561964400000
# 4  The August race is now open and is the fourth ...  1564642800000
#
#        CloseTime                                           TrackArn  Status  \
# 0  1556550000000  arn:aws:deepracer:us-east-1::track/Virtual_Com...  CLOSED
# 1  1559347199000  arn:aws:deepracer:us-east-1::track/Virtual_May...  CLOSED
# 2  1561964399000  arn:aws:deepracer:us-east-1::track/Tokyo_Racin...  CLOSED
# 3  1564599599000  arn:aws:deepracer:us-east-1::track/New_YorkAlt...  CLOSED
# 4  1567295999000  arn:aws:deepracer:us-east-1::track/ChinaAlt_track  CLOSED
#
#    MinimumLaps  TotalLaps  ParticipantCount    RaceType Visibility  \
# 0            3          5               162  TIME_TRIAL    VISIBLE
# 1            2          5               859  TIME_TRIAL    VISIBLE
# 2            1          5               572  TIME_TRIAL    VISIBLE
# 3            1          5               650  TIME_TRIAL    VISIBLE
# 4            1          5              1375  TIME_TRIAL    VISIBLE
#
#    TimingMethod LeagueType  Moderated TermsConditionId TermsAccepted  \
# 0  AVG_LAP_TIME    VIRTUAL      False              NaN           NaN
# 1  AVG_LAP_TIME    VIRTUAL      False              NaN           NaN
# 2  AVG_LAP_TIME    VIRTUAL      False              NaN           NaN
# 3  AVG_LAP_TIME    VIRTUAL      False              NaN           NaN
# 4  AVG_LAP_TIME    VIRTUAL      False              NaN           NaN
#
#   WinnerAlias HeadToHeadConfig_HeadToHeadType  HeadToHeadConfig_NumBotCars  \
# 0         NaN                             NaN                          NaN
# 1         NaN                             NaN                          NaN
# 2         NaN                             NaN                          NaN
# 3         NaN                             NaN                          NaN
# 4         NaN                             NaN                          NaN
#
#    HeadToHeadConfig_BotCarSpeed HeadToHeadConfig_EnableLaneChange  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
#
#    HeadToHeadConfig_LowerLaneChangeTime  HeadToHeadConfig_UpperLaneChangeTime  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#   ResettingBehaviorConfig_IsContinuousLap ResettingBehaviorConfig_AllowReset  \
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
#
#    ResettingBehaviorConfig_MaxResetTimes  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    ResettingBehaviorConfig_PenaltySeconds  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   PlayoffRaceTypeConfig_PlayoffRaceTypeID ThemeConfig_ThemeID  \
# 0                                     NaN                 NaN
# 1                                     NaN                 NaN
# 2                                     NaN                 NaN
# 3                                     NaN                 NaN
# 4                                     NaN                 NaN
#
#   ObjectAvoidanceConfig_RandomizeLocation  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   ObjectAvoidanceConfig_ObstaclePositions  ObjectAvoidanceConfig_NumObstacles  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
#
#   ObjectAvoidanceConfig_ObstacleType  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#    ResettingBehaviorConfig_CollisionPenaltySeconds  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    ResettingBehaviorConfig_OffTrackPenaltySeconds  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   PlayoffRaceTypeConfig_PlayoffRaceArn  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    PlayoffRaceTypeConfig_PlayoffReleaseTime  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    PlayoffRaceTypeConfig_PlayoffResultReleaseTime  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    NumOfTeamSubmissionsRequired  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#   ParticipationConfig_EntryTypeConfig_InvitationEntryType  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ParticipationConfig_ViewType CarControlConfig_CarSpeedControl Tags  \
# 0                          NaN                              NaN  NaN
# 1                          NaN                              NaN  NaN
# 2                          NaN                              NaN  NaN
# 3                          NaN                              NaN  NaN
# 4                          NaN                              NaN  NaN
#
#   RacingDivision ParticipationConfig_EntryTypeConfig_RacingDivisionEntryType  \
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            NaN                                                NaN
#
#    TerminationConditions_MaxTimeInMinutes
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN

# %%
months_races = ['2020 June Qualifier']

race_type = ['TIME_TRIAL']

# Get Arn URLs according to race type: HEAD_TO_HEAD_RACING – month qualifier leader board and OBJECT_AVOIDANCE – final race
month_leaderboard_arn = df_leaderboards.loc[(df_leaderboards['Name'].isin(months_races)) & (df_leaderboards['RaceType'].isin(race_type))]['Arn'].values
month_final_arn = df_leaderboards.loc[(df_leaderboards['Name'].isin(months_races)) & (df_leaderboards['RaceType'].isin(race_type))]['Arn'].values

# Next we need to get raw data for final races and month qualifier leader. We put dataframes to lists: one for month qualifier and second for winners
path = "https://raw.githubusercontent.com/aws-deepracer-community/deepracer-race-data/main/raw_data/leaderboards/"
suffix = "/FINAL.csv"

list_end_of_month=[]
for arn_leaderboard in month_leaderboard_arn:
  try: 
    list_end_of_month.append(pd.read_csv(path+month_leaderboard_arn[np.where(month_leaderboard_arn == arn_leaderboard)[0][0]].replace(":", "%3A")+suffix))
  except urllib.error.HTTPError as err:
    list_end_of_month.append(pd.DataFrame(columns=['Alias', 'UserId', 'Rank', 'Month']))


list_finale=[]
for arn_win in month_final_arn:
  try:
    list_finale.append(pd.read_csv(path+month_final_arn[np.where(month_final_arn == arn_win)[0][0]].replace(":", "%3A")+suffix))
  except urllib.error.HTTPError as err:
    list_finale.append(pd.DataFrame(columns=['Alias', 'UserId', 'Rank', 'Month']))
    pass

# %%
list_finale[0].sort_values(by = 'AvgLapTime', inplace = True)
list_finale[0].head()
# Out:
#              Alias  SubmissionTime  LapCount  AvgLapTime  BestLapTime  \
# 0               JJ   1593348426631         3       19828        19137
# 1  ChihYu-NCTU-CGI   1593162366455         3       19920        19664
# 2         Karl-NAB   1593410217979         3       22504        21992
# 3        Duckworth   1593543799879         3       24106        23864
# 4         RayG-DBS   1591228980366         3       24604        23986
#
#    TotalLapTime  AvgResets  CollisionCount  OffTrackCount  ResetCount  \
# 0         59484        0.0               0              0           0
# 1         59760        0.0               0              0           0
# 2         67512        0.0               0              0           0
# 3         72319        0.0               0              0           0
# 4         73814        0.0               0              0           0
#
#    SubmissionCount  Rank LeaderboardSubmissionStatusType  RankingScore  \
# 0             5452     1                         SUCCESS         59484
# 1              982     2                         SUCCESS         59760
# 2             5374     3                         SUCCESS         67512
# 3               10     4                         SUCCESS         72319
# 4              363     5                         SUCCESS         73814
#
#                    UserId
# 0  afdcX_4vRH6Ussd0mbg5LQ
# 1  ihXnNlRDTz2-KvgATVkREw
# 2  4vOOxLIsSjeL2WFaO5o_fQ
# 3  VIu9BQ4-Th6gUqu60ztwUQ
# 4  YNrvM9f5RteeSrCl7oFC5w

# %%
list_finale[0].shape
# Out:
# (959, 15)

# %%
month_final_arn[0] == arn_leaderboard
# Out:
# True

# %%
arn_leaderboard
# Out:
# 'arn:aws:deepracer:us-east-1::leaderboard/virtual-season-2020-06-tt'

# %%
path+month_final_arn[np.where(month_final_arn == arn_win)[0][0]]+suffix
# Out:
# 'https://raw.githubusercontent.com/aws-deepracer-community/deepracer-race-data/main/raw_data/leaderboards/arn:aws:deepracer:us-east-1::leaderboard/virtual-season-2020-06-tt/FINAL.csv'
